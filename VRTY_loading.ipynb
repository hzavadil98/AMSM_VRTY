# %% [markdown]
# <a href="https://colab.research.google.com/github/hzavadil98/AMSM_VRTY/blob/main/VRTY_loading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
# downloads the data in a pickle file to colab environment
# !gdown 1KnozeA5tLxrxjH-CDP_bqf9m_3sIrUcv
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1KnozeA5tLxrxjH-CDP_bqf9m_3sIrUcv
# From (redirected): https://drive.google.com/uc?id=1KnozeA5tLxrxjH-CDP_bqf9m_3sIrUcv&confirm=t&uuid=9448c6db-e71b-4685-9672-971ea07bf388
# To: /content/VRTY_student.pkl
# 100% 2.40G/2.40G [00:16<00:00, 142MB/s]

# %% [markdown]
# ## Loading VRTY dataset

# %%
# Replace with your filepath to VRTY_student.pkl file, use r prefix for windows filesystem as below
path_to_pickle_file = '/content/VRTY_student.pkl'

# %%
# Load the dictionary stored in VRTY_student.pkl
with open(path_to_pickle_file, 'rb') as pickle_file:
    load = pickle.load(pickle_file)

# %%
# Unpack the dictionary
train_dataset = load['train_data']
train_labels = load['train_labels']
eval_dataset = load['eval_data']

# %%
print(f'train_dataset is a {type(train_dataset[0,0])}  array of shape  {train_dataset.shape} with corresponding train_labels, a {type(train_labels[0])} array of length {train_labels.shape}. eval_dataset is an array of the same structure as train_dataset with shape {eval_dataset.shape}.')
# Out:
# train_dataset is a <class 'numpy.ndarray'>  array of shape  (11250, 4, 6000) with corresponding train_labels, a <class 'numpy.int64'> array of length (11250,). eval_dataset is an array of the same structure as train_dataset with shape (1250, 4, 6000).

# %% [markdown]
# The goal is to use labeled train_dataset to create a classification model. The model is then used to predict unknown labels of observations in eval_dataset, these predictions will be submitted to independently evaluate the accuracy of your model. Make sure not to shuffle the the observations in eval_dataset.

# %% [markdown]
# ## Structure of the data
# The underlying dataset is composed of observations in the form of 4 channels of AE signal of length 6000. One data sample is visualised below. The observations come from five different classes.

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

axs[0, 0].plot(train_dataset[0, 0, :])
axs[0, 0].set_title('Channel 1')

axs[0, 1].plot(train_dataset[0, 1, :])
axs[0, 1].set_title('Channel 2')

axs[1, 0].plot(train_dataset[0, 2, :])
axs[1, 0].set_title('Channel 3')

axs[1, 1].plot(train_dataset[0, 3, :])
axs[1, 1].set_title('Channel 4')

fig.text(0.52, -0.02, 'Time', ha='center', va='center', size = 16)
fig.text(-0.02, 0.5, 'Signal', ha='center', va='center', rotation='vertical', size = 16)

fig.suptitle('One data sample', fontsize=20)
# Adjust layout to prevent overlap of titles and labels
plt.tight_layout()

# Show the plot
plt.show()
